# %%
# %matplotlib inline
import mathplotlib.pyplot as plt

voltage = [0 , -10**3 , -10**6 , -10**9 , -10**12 , -10**15 ]
frequency = [10**9 , 10**14 , 10**15 , 10**17 , 10**18 , 10**20]

plt.plot(voltage , time)
plt.xlabel("voltage (v)") 
plt.ylabel("frequency (hz)")
